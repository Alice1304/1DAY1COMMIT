# %% [markdown]
# <a href="https://colab.research.google.com/github/Alice1304/1day1commit/blob/main/%ED%8C%8C.%EB%A8%B8.%ED%8C%90.%EB%8D%B0./Part1/dataframe2_0928.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# 행 인덱스/열 이름 지정하여, 데이터프레임 만들기
df = pd.DataFrame([[13, '남', '플래디스'], ['무한', '남', 'sm']], 
                   index=['세븐틴', 'nct'],
                   columns=['인원', '성별', '소속사'])

# %%
df
# Out:
#      인원 성별   소속사
# 세븐틴  13  남  플래디스
# nct  무한  남    sm

# %%
df.index=['seventeen', 'NCT']
df.columns=['인원수', '남/녀', '소속']

# %%
df
# Out:
#           인원수 남/녀    소속
# seventeen  13   남  플래디스
# NCT        무한   남    sm

# %%
#rename 이용해 특정 행/열만 바꾸기

# %%
df.rename(columns={'인원수':'명수'}, inplace=True)
df.rename(index={'seventeen':'Seventeen'},inplace=True)

# %%
df
# Out:
#            명수 남/녀    소속
# Seventeen  13   남  플래디스
# NCT        무한   남    sm

# %%
#행/열삭제하기


df1= df.copy()

# %%
df1
# Out:
#            명수 남/녀    소속
# Seventeen  13   남  플래디스
# NCT        무한   남    sm

# %%
df1.drop('Seventeen',inplace=True)
df1
# Out:
#      명수 남/녀  소속
# NCT  무한   남  sm

# %%
df2=df.copy()

# %%
df2
# Out:
#            명수 남/녀    소속
# Seventeen  13   남  플래디스
# NCT        무한   남    sm

# %%
df2.drop('명수',axis=1, inplace=True)
df2
# Out:
#           남/녀    소속
# Seventeen   남  플래디스
# NCT         남    sm

# %%
seventeen1 = df.iloc[0]
seventeen1
# Out:
# 명수       13
# 남/녀       남
# 소속     플래디스
# Name: Seventeen, dtype: object

# %%
seventeen2 = df.loc['Seventeen']
seventeen2
# Out:
# 명수       13
# 남/녀       남
# 소속     플래디스
# Name: Seventeen, dtype: object

# %%
df.명수
# Out:
# Seventeen    13
# NCT          무한
# Name: 명수, dtype: object

# %%
df['명수']
# Out:
# Seventeen    13
# NCT          무한
# Name: 명수, dtype: object

# %%
df[['명수']]
# Out:
#            명수
# Seventeen  13
# NCT        무한

# %%
df[['명수','소속']]
# Out:
#            명수    소속
# Seventeen  13  플래디스
# NCT        무한    sm
